# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()
y = [4.2,7.69,11.9,26.7,47.9,84.6]
x= [60,80,100,150,200,250]

sns.pointplot(x=x,y=y)
plt.xlabel("Lattice Size")
plt.ylabel("Run Time")
plt.title("MPI Speed vs Lattice Size")
# Out:
# Text(0.5, 1.0, 'MPI Speed vs Lattice Size')
